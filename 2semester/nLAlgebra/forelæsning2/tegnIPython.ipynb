# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#punkterne x og y svarer til flere punkter (i dette tilfælde 6 punkter) i et koordinatsystem 
x = np.array([-0.5, 0.0, 1.0, 2.0, 3.0, 4.0])
y = np.array([1.5, 2.0, 0.0, 1.5, 0.0, 2.0])

# %%
x
# Out:
# array([-0.5,  0. ,  1. ,  2. ,  3. ,  4. ])

# %%
y
# Out:
# array([1.5, 2. , 0. , 1.5, 0. , 2. ])

# %%
fig, ax = plt.subplots()
#espect er med til at få orden i koordinatsystemtet
ax.set_aspect('equal')
ax.plot(x, y)

# %%
#Graffen bliver nu flyttet
a = 1.0
b = 0.5
c = 0.0
d = 1.0

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
#Se forelæsning 2 slides (slide 13) for formel
ax.plot(a*x + b*y, c*x + d*y)

# %%
#Graffen bliver roteret (se forlæsning 2, slide 15)
a = np.cos(np.pi/3)
b = -np.sin(np.pi/3)
c = np.sin(np.pi/3)
d = np.cos(np.pi/3)

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
#Se forelæsning 2 slides (slide 13) for formel
ax.plot(a*x + b*y, c*x + d*y)

# %%
#Graffen gemmes
fig.savefig("fig-rotation.pdf")

# %%
#Skift farve på firgur
fig, ax = plt.subplots()
ax.set_aspect('equal')
#Se forelæsning 2 slides (slide 13) for formel
ax.plot(a*x + b*y, c*x + d*y, color="red")

# %%
#Marker punkter i koordinatsystemet
fig, ax = plt.subplots()
ax.set_aspect('equal')
#Se forelæsning 2 slides (slide 13) for formel
ax.plot(a*x + b*y, c*x + d*y, marker="o")

# %%
#plot af funktioner (i dette tilfælde cos)
t = np.linspace(0, 2*np.pi, 100)
t
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
type(t)
# Out:
# numpy.ndarray

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.plot(t, np.cos(t))

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
#Plot cos i x retning og sin i y retning (dette giver enhedscirklen)
ax.plot(np.cos(t), np.sin(t))

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-2.5, 2.5)
#Se forelæsning 2 slides (slide 13) for formel
ax.plot(np.cos(t), np.sin(t))
